# %%
#%pylab
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
#%matplotlib inline
from sklearn.model_selection import train_test_split
train_data1=np.load('../data0.npy')
lab_data1=np.load('../lab0.npy')
i=9997
#plt.plot(train_data1[i])
#imshow(train_data1[i])
#print(lab_data1[i])
#print(train_data1[0].shape)
X_train, X_test, y_train, y_test = train_test_split(train_data1, lab_data1, test_size=0.33)
X_train = X_train.astype('float32')/255
X_test = X_test.astype('float32')/255
model=tf.keras.Sequential()
model.add(tf.keras.layers.Conv2D(filters=64, kernel_size=(2,2),strides=(1, 1), padding='same', activation='relu', input_shape=(40,168,1))) 
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2,2)))
model.add(tf.keras.layers.Dropout(0.3))
model.add(tf.keras.layers.Conv2D(filters=32, kernel_size=(2,2),strides=(1, 1), padding='same', activation='relu'))
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2,2)))
model.add(tf.keras.layers.Dropout(0.3))
model.add(tf.keras.layers.Conv2D(filters=32, kernel_size=(2,2),strides=(1, 1), padding='same', activation='relu'))
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2,2)))
model.add(tf.keras.layers.Dropout(0.3))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(256, activation='relu'))
model.add(tf.keras.layers.Dropout(0.5))
model.add(tf.keras.layers.Dense(37, activation='softmax'))
# Take a look at the model summary
model.summary()
model.compile(loss='sparse_categorical_crossentropy',
             optimizer='adam',
             metrics=['accuracy'])
X_train = X_train.reshape(-1,40,168,1)
X_test = X_test.reshape(-1,40, 168, 1)
model_log=model.fit(X_train, y_train,
          batch_size=5,
          epochs=10,
          verbose=1,
          validation_split=.3)
score = model.evaluate(X_test, y_test, verbose=0)
print(score[1])
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 40, 168, 64)       320
#
#  max_pooling2d_3 (MaxPooling  (None, 20, 84, 64)       0
#  2D)
#
#  dropout_4 (Dropout)         (None, 20, 84, 64)        0
#
#  conv2d_4 (Conv2D)           (None, 20, 84, 32)        8224
#
#  max_pooling2d_4 (MaxPooling  (None, 10, 42, 32)       0
#  2D)
#
#  dropout_5 (Dropout)         (None, 10, 42, 32)        0
#
#  conv2d_5 (Conv2D)           (None, 10, 42, 32)        4128
#
#  max_pooling2d_5 (MaxPooling  (None, 5, 21, 32)        0
#  2D)
#
#  dropout_6 (Dropout)         (None, 5, 21, 32)         0
#
#  flatten_1 (Flatten)         (None, 3360)              0
#
#  dense_2 (Dense)             (None, 256)               860416
#
#  dropout_7 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 37)                9509
#
# =================================================================
# Total params: 882,597
# Trainable params: 882,597
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 938/938 [==============================] - 52s 53ms/step - loss: 3.2375 - accuracy: 0.0557 - val_loss: 3.1890 - val_accuracy: 0.0682
# Epoch 2/10
# 938/938 [==============================] - 51s 55ms/step - loss: 3.1963 - accuracy: 0.0578 - val_loss: 3.1855 - val_accuracy: 0.0731
# Epoch 3/10
# 938/938 [==============================] - 52s 56ms/step - loss: 3.1790 - accuracy: 0.0629 - val_loss: 3.1798 - val_accuracy: 0.0672
# Epoch 4/10
# 938/938 [==============================] - 46s 49ms/step - loss: 3.1627 - accuracy: 0.0733 - val_loss: 3.1814 - val_accuracy: 0.0582
# Epoch 5/10
# 938/938 [==============================] - 46s 49ms/step - loss: 3.1430 - accuracy: 0.0821 - val_loss: 3.1941 - val_accuracy: 0.0726
# Epoch 6/10
# 938/938 [==============================] - 47s 51ms/step - loss: 3.1085 - accuracy: 0.0883 - val_loss: 3.1888 - val_accuracy: 0.0567
# Epoch 7/10
# 938/938 [==============================] - 52s 55ms/step - loss: 3.0526 - accuracy: 0.1151 - val_loss: 3.1880 - val_accuracy: 0.0537
# Epoch 8/10
# 938/938 [==============================] - 52s 56ms/step - loss: 2.9804 - accuracy: 0.1243 - val_loss: 3.1670 - val_accuracy: 0.0587
# Epoch 9/10
# 938/938 [==============================] - 47s 51ms/step - loss: 2.8998 - accuracy: 0.1522 - val_loss: 3.1666 - val_accuracy: 0.0582
# Epoch 10/10
# 938/938 [==============================] - 49s 52ms/step - loss: 2.8197 - accuracy: 0.1665 - val_loss: 3.1712 - val_accuracy: 0.0647
# 0.06454545259475708
